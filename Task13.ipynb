# %% [markdown]
# ## Task 13

# %% [markdown]
# - Generate n - Table using pandas series
#
# * 1 -- 5
# * 2 -- 10
# * 3 -- 15

# %%
import numpy as np
import pandas as pd

# %%
n = int(input())
table = pd.Series(np.arange(1,n+1)*5, index = np.arange(1,n+1))
table
# Out:
# 1      5
# 2     10
# 3     15
# 4     20
# 5     25
# 6     30
# 7     35
# 8     40
# 9     45
# 10    50
# dtype: int32

# %% [markdown]
# ### Ex1 - Getting and knowing your Data
# #### Step 1. Go to Dataset_link
# - There are many kinds of birds: pigeons, ducks, ostriches, penguins… Some are good at flying, others can't fly but run fast. Some swim under water, others wading in shallow pool.
#
# - According to their living environments and living habits, birds are classified into different ecological groups. There are 6 ecological groups of birds:
# - Swimming Birds
# - Wading Birds
# - Terrestrial Birds
# - Raptors
# - Scansorial Birds
# - Singing Birds

# %% [markdown]
# #### Step 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# #### Step 3. Use the Csv file and assign it to a dataframe called birds

# %%
birds = pd.read_csv('bird.csv')
birds
# Out:
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw  \
# 0      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ..   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# 415  415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# 416  416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# 417  417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# 418  418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# 419  419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
#     type
# 0     SW
# 1     SW
# 2     SW
# 3     SW
# 4     SW
# ..   ...
# 415   SO
# 416   SO
# 417   SO
# 418   SO
# 419   SO
#
# [420 rows x 12 columns]

# %% [markdown]
# #### Step 4. See the random 5 entries

# %%
birds.sample(5)
# Out:
#       id    huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw  \
# 263  263   31.72  2.64   40.00   1.99  20.36  1.59   32.21  1.62  17.72  1.52
# 237  237  119.12  7.57  137.37   6.06  75.53  6.35  115.02  6.22  60.99  7.91
# 291  291   41.60  3.74   56.50   3.02  37.00  2.99   62.90  2.82  38.21  2.51
# 210  210   52.88  4.47   62.02   3.76  47.09  3.64   63.42  3.40  54.54  2.90
# 191  191   32.34  3.17   29.05   2.36  39.64  2.70   55.36  2.51  37.08  2.22
#
#     type
# 263    P
# 237    R
# 291    P
# 210    R
# 191    T

# %% [markdown]
# #### Step 5. What is the number of observations in the dataset

# %%
birds.count()
# Out:
# id       420
# huml     419
# humw     419
# ulnal    417
# ulnaw    418
# feml     418
# femw     419
# tibl     418
# tibw     419
# tarl     419
# tarw     419
# type     420
# dtype: int64

# %% [markdown]
# #### Step 6. What is the number of columns in the dataset

# %%
len(birds.columns)
# Out:
# 12

# %% [markdown]
# #### Step 7. Print the name of all the columns

# %%
for col in birds:
    print(col)
# Out:
# id
# huml
# humw
# ulnal
# ulnaw
# feml
# femw
# tibl
# tibw
# tarl
# tarw
# type

# %% [markdown]
# #### Step 8. What is the name of 10th column

# %%
birds.columns[9] #index starts with 0
# Out:
# 'tarl'

# %% [markdown]
# #### Step 9. What is the type of the observations of the 2th column

# %%
col_two = birds.columns[1]
print(col_two)
birds[col_two].dtypes
# Out:
# huml
# dtype('float64')

# %% [markdown]
# #### Step 10. How is the dataset indexed

# %%
birds.index
# Out:
# RangeIndex(start=0, stop=420, step=1)

# %% [markdown]
# #### Step 11. Set the 'type' column as the index of the dataframe

# %%
birds.set_index('type', inplace = True)

# %%
birds
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ...   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# SO    415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# SO    416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# SO    417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# SO    418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
# [420 rows x 11 columns]

# %% [markdown]
# #### Step 12. Print only the column huml

# %%
birds['huml']
# Out:
# type
# SW    80.78
# SW    88.91
# SW    79.97
# SW    77.65
# SW    62.80
#       ...
# SO    17.96
# SO    19.21
# SO    18.79
# SO    20.38
# SO    17.89
# Name: huml, Length: 420, dtype: float64

# %% [markdown]
# #### Step 13. Print the "huml","humw" columns from SW and P

# %%
from_col = birds.loc[['SW','P']]
data1 = from_col[['huml','humw']]
data1
# Out:
#        huml  humw
# type
# SW    80.78  6.68
# SW    88.91  6.63
# SW    79.97  6.37
# SW    77.65  5.70
# SW    62.80  4.84
# ...     ...   ...
# P     27.72  2.67
# P     29.14  2.75
# P     27.85  2.65
# P     20.06  1.73
# P     41.60  3.74
#
# [154 rows x 2 columns]

# %% [markdown]
# #### Step 14. Select the rows 3 to 7 and the columns 3 to 6

# %%
birds.iloc[[2,3,4,5,6],[2,3,4,5]]
# Out:
#       humw  ulnal  ulnaw   feml
# type
# SW    6.37  69.26   5.28  43.07
# SW    5.70  65.76   4.77  40.04
# SW    4.84  52.09   3.73  33.95
# SW    4.78  50.46   3.47  49.52
# SW    5.94  67.39   4.50  42.07

# %% [markdown]
# #### Step 15. Select rows where df.femw is greater than 5.2 and less than 10.5

# %%
birds[(birds.femw >= 5.2) & (birds.femw < 10.5)]
# Out:
#        id    huml   humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  \
# type
# SW      8  118.20   7.82  116.64   6.13  59.33  5.45  110.00  5.58  61.62
# SW      9  145.00  10.42  144.00   7.05  70.96  7.44  120.00  7.31  78.67
# SW     10  165.00  11.45  156.00   8.68  80.25  7.85  143.00  8.25  86.61
# SW     11  186.00   9.83  152.00   8.76  56.02  7.02  185.00  8.07  90.80
# SW     12  172.00   8.44  142.00   8.43  52.18  6.68  180.00  9.62  82.58
# ...   ...     ...    ...     ...    ...    ...   ...     ...   ...    ...
# R     237  119.12   7.57  137.37   6.06  75.53  6.35  115.02  6.22  60.99
# R     238  117.43   7.13  136.26   5.51  75.54  5.85  115.30  5.45  59.45
# R     239  116.85   7.43  134.80   6.19  73.51  6.10  112.66  5.94  61.25
# R     240  119.58   8.04  138.39   6.25  76.36  6.50  115.90  6.07  59.90
# R     241  126.88   8.01  148.47   6.59  81.42  6.71  124.05  6.58  64.57
#
#       tarw
# type
# SW    4.37
# SW    6.34
# SW    6.63
# SW    4.59
# SW    5.50
# ...    ...
# R     7.91
# R     8.25
# R     6.90
# R     6.92
# R     7.97
#
# [71 rows x 11 columns]

# %% [markdown]
# #### Step 16. Select the third cell down in the column named tarl

# %%
birds['tarl'].iloc[2]
# Out:
# 38.31

# %% [markdown]
# #### Step 17. Compute how many values are non-missing for each feature over the entire record

# %%
birds.notnull().sum()
# Out:
# id       420
# huml     419
# humw     419
# ulnal    417
# ulnaw    418
# feml     418
# femw     419
# tibl     418
# tibw     419
# tarl     419
# tarw     419
# dtype: int64

# %% [markdown]
# #### Step 18. Calculate Mean and Median of "tibl" and "tibw" columns

# %%
birds['tibl'].mean()
# Out:
# 64.66282296650718

# %%
birds['tibl'].median()
# Out:
# 52.120000000000005

# %%
birds['tibw'].mean()
# Out:
# 3.1823389021479733

# %%
birds['tibw'].median()
# Out:
# 2.49

# %% [markdown]
# #### Step19. Discover what is the mean "ulnaw" per every bird category (use Groupby)

# %%
birds
# Out:
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW      0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW      1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW      2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW      3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW      4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
# ...   ...    ...   ...    ...    ...    ...   ...    ...   ...    ...   ...
# SO    415  17.96  1.63  19.25   1.33  18.36  1.54  31.25  1.33  21.99  1.15
# SO    416  19.21  1.64  20.76   1.49  19.24  1.45  33.21  1.28  23.60  1.15
# SO    417  18.79  1.63  19.83   1.53  20.96  1.43  34.45  1.41  22.86  1.21
# SO    418  20.38  1.78  22.53   1.50  21.35  1.48  36.09  1.53  25.98  1.24
# SO    419  17.89  1.44  19.26   1.10  17.62  1.34  29.81  1.24  21.69  1.05
#
# [420 rows x 11 columns]

# %%
g = birds.groupby('type')
g

# %%
for b, b_type in g:
    print("\n\n",b,"\n\n")
    print(b_type.head())
# Out:
#  P
#
#
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# P     254  29.26  2.66  27.63   2.23  27.87  2.03  38.90  1.81  25.22  1.62
# P     255  30.60  2.45  25.90   1.87  32.36  2.10  50.25  1.88  33.58  1.88
# P     256  30.25  2.29  25.14   1.87  31.61  2.18  50.98  2.00  33.50  1.93
# P     257  42.52  2.99  36.73   2.91  52.24  3.81  81.57  3.71  61.27  2.71
# P     258  45.60  3.35  38.73   3.52  54.45  4.10  83.59  3.72  63.91  2.67
#
#
#  R
#
#
#        id   huml  humw   ulnal  ulnaw   feml  femw    tibl  tibw   tarl  tarw
# type
# R     204  63.76  4.74     NaN    NaN  57.33  4.88   75.67  4.33  60.19  3.82
# R     205  57.48  4.74   69.06   4.08  57.56  4.80   80.16  4.25  60.54  3.78
# R     206  62.49  4.75   69.66   3.99  57.30  4.60   77.60  4.26  60.31  3.86
# R     207  98.08  7.77  113.04   5.76  82.04  7.17  107.47  6.65    NaN   NaN
# R     208  54.47  4.37   63.29   3.32  47.83  3.45   64.25  3.15  54.97  2.86
#
#
#  SO
#
#
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SO    292  29.61  2.41  33.93   2.02  30.79  2.19  51.64  2.01  37.33  1.78
# SO    293  30.28  2.89  35.37   2.15  31.09  2.51  53.36  2.31  39.52  1.69
# SO    294  28.10  2.44  32.50   2.19  29.68  2.33  50.47  2.21  37.98  1.79
# SO    295  28.66  2.48  33.24   2.02  29.33  2.26  50.64  2.05  35.99  1.85
# SO    296  36.36  3.31  40.51   2.56  37.52  2.85  53.96  2.63  42.71  2.41
#
#
#  SW
#
#
#       id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# SW     0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# SW     1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# SW     2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# SW     3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# SW     4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13
#
#
#  T
#
#
#        id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# type
# T     181  43.97  4.64  51.07   3.80  38.76  3.18  55.67  2.88  30.41  2.83
# T     182  44.58  5.76  52.76   4.84  40.47  3.76  56.42  3.31  31.32  3.34
# T     183  20.25  2.35  25.14   1.76  20.17  1.37  27.67  1.41  15.68  1.55
# T     184  48.70  5.46  57.39   3.73  42.56  3.07  52.42  2.85  27.23  3.03
# T     185  35.74  3.91  39.20   2.93  33.01  2.65  42.80  2.18  24.85  2.34
#
#
#  W
#
#
#        id    huml   humw   ulnal  ulnaw    feml  femw    tibl  tibw    tarl  \
# type
# W     116  157.00   9.00  192.00   7.02   85.60  6.44  227.00  6.84  175.00
# W     117  190.00  11.92  225.00   8.55  101.75  7.75  240.00  7.71  175.00
# W     118   70.01   3.71   76.90   2.88   49.42  3.08   79.56  3.35   52.74
# W     119   92.93   5.28  110.94   3.87   55.11  4.16  137.00  4.29   96.37
# W     120  118.52   6.87  134.91   5.06   78.20  5.24  132.00  5.38   85.28
#
#       tarw
# type
# W     6.77
# W     7.00
# W     3.02
# W     3.79
# W     4.74

# %%
g['ulnaw'].mean()
# Out:
# type
# P     2.476316
# R     4.813265
# SO    1.743858
# SW    5.221638
# T     3.471739
# W     4.102615
# Name: ulnaw, dtype: float64

# %% [markdown]
# #### Step20. Plot graph between all features refuse "type" and "id" columns

# %%
birds2 = birds.copy()

# %%
birds2.reset_index(inplace= True)
birds2.head()
# Out:
#   type  id   huml  humw  ulnal  ulnaw   feml  femw   tibl  tibw   tarl  tarw
# 0   SW   0  80.78  6.68  72.01   4.88  41.81  3.70   5.50  4.03  38.70  3.84
# 1   SW   1  88.91  6.63  80.53   5.59  47.04  4.30  80.22  4.51  41.50  4.01
# 2   SW   2  79.97  6.37  69.26   5.28  43.07  3.90  75.35  4.04  38.31  3.34
# 3   SW   3  77.65  5.70  65.76   4.77  40.04  3.52  69.17  3.40  35.78  3.41
# 4   SW   4  62.80  4.84  52.09   3.73  33.95  2.72  56.27  2.96  31.88  3.13

# %%
birds2.drop(['type'], axis = 1, inplace= True)
birds2.drop(['id'], axis = 1, inplace= True)

# %%
birds2.plot() #graph between all features except "type" and "id" columns
# Out:
# <AxesSubplot:>
